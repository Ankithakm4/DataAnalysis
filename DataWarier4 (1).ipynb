# %%
import requests

url = "https://reuters-business-and-financial-news.p.rapidapi.com/market-rics/list-rics-by-asset-and-category/1/1"

headers = {
	"x-rapidapi-key": "88591c7d30msh31dc723b7c98a4cp17bdc1jsn4c57173e870f",
	"x-rapidapi-host": "reuters-business-and-financial-news.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

result=response.json()

# %%
import pandas as pd
newsdata=pd.DataFrame(result)
newsdata.head()
# Out:
#    statusCode  marketAsset marketCategory  \
# 0         200  Commodities    Agriculture
#
#                                            assetData
# 0  {'typeName': 'Commodity Future', 'rics': ['Cc1...

# %% [markdown]
# Random fox

# %%
import requests
page=requests.get('https://randomfox.ca/floor')

# %%
print(page)
# Out:
# <Response [404]>

# %%
import requests
page1=requests.get('http://api.weatherapi.com/v1/current.json?key=5e4f5435917a480090b90647252003&q=Tumkur')

# %%
print(page1)
# Out:
# <Response [200]>

# %%
weather=page1.json()
print(weather)
# Out:
# {'location': {'name': 'Tumkur', 'region': 'Karnataka', 'country': 'India', 'lat': 13.3422, 'lon': 77.1017, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1742462999, 'localtime': '2025-03-20 14:59'}, 'current': {'last_updated_epoch': 1742462100, 'last_updated': '2025-03-20 14:45', 'temp_c': 34.6, 'temp_f': 94.2, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 9.4, 'wind_kph': 15.1, 'wind_degree': 113, 'wind_dir': 'ESE', 'pressure_mb': 1011.0, 'pressure_in': 29.85, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 18, 'cloud': 4, 'feelslike_c': 32.7, 'feelslike_f': 90.8, 'windchill_c': 34.6, 'windchill_f': 94.2, 'heatindex_c': 32.7, 'heatindex_f': 90.8, 'dewpoint_c': 6.6, 'dewpoint_f': 43.9, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 9.2, 'gust_mph': 10.8, 'gust_kph': 17.4}}

# %%
import requests

# %%
page1=requests.get('http://api.coincap.io/v2/assets')

# %%
print(page1)
# Out:
# <Response [200]>

# %%
result=page1.json()
print(result)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19839400.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1702961121446.4556401219293600', 'volumeUsd24Hr': '10138528079.2398822948345422', 'priceUsd': '85837.3298308646249444', 'changePercent24Hr': '2.7137175170941033', 'vwap24Hr': '85242.5393622283315806', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120629195.4269564900000000', 'maxSupply': None, 'marketCapUsd': '241692459048.7153819697478160', 'volumeUsd24Hr': '6622719868.9685518991892749', 'priceUsd': '2003.5983676527564952', 'changePercent24Hr': '2.9898914432433636', 'vwap24Hr': '2024.2133024845636723', 'explorer': 'https://etherscan.io/'}, {'id': 'xrp', 'rank': '3', 'symbol': 'XRP', 'name': 'XRP', 'supply': '58108919817.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '145740990024.5145867962853678', 'volu
# ...

# %%
coindata=result['data']
import pandas as pd
mydf=pd.DataFrame(coindata)

# %%
mydf.head(10)
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19839400.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120629195.4269564900000000
# 2           xrp    3    XRP       XRP   58108919817.0000000000000000
# 3        tether    4   USDT    Tether  143653509034.0653000000000000
# 4  binance-coin    5    BNB       BNB     144006830.0000000000000000
# 5        solana    6    SOL    Solana     510156044.0299182000000000
# 6      usd-coin    7   USDC      USDC   59242276090.4832400000000000
# 7       cardano    8    ADA   Cardano   35234797228.4508800000000000
# 8      dogecoin    9   DOGE  Dogecoin  148504846383.7052600000000000
# 9          tron   10    TRX      TRON   95016082389.9211600000000000
#
#                        maxSupply                    marketCapUsd  \
# 0      21000000.0000000000000000  1702961121446.4556401219293600
# 1                           None   241692459048.7153819697478160
# ...

# %%
mydf.to_csv(r"C:\myfiles_python\data.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\myfiles_python\crytodata.csv")
df.head()
# Out:
#    Unnamed: 0            id  rank symbol      name        supply  \
# 0           0       bitcoin     1    BTC   Bitcoin  1.983940e+07
# 1           1      ethereum     2    ETH  Ethereum  1.206292e+08
# 2           2           xrp     3    XRP       XRP  5.810892e+10
# 3           3        tether     4   USDT    Tether  1.436535e+11
# 4           4  binance-coin     5    BNB       BNB  1.440068e+08
#
#       maxSupply  marketCapUsd  volumeUsd24Hr      priceUsd  changePercent24Hr  \
# 0  2.100000e+07  1.702961e+12   1.013853e+10  85837.329831           2.713718
# 1           NaN  2.416925e+11   6.622720e+09   2003.598368           2.989891
# 2  1.000000e+11  1.457410e+11   3.367515e+09      2.508066           8.384786
# 3           NaN  1.437052e+11   2.466155e+10      1.000360           0.102417
# 4  1.440068e+08  9.062249e+10   5.605916e+08    629.292982           2.280616
#
#        vwap24Hr                                           explorer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   id                 100 non-null    object
#  2   rank               100 non-null    int64
#  3   symbol             100 non-null    object
#  4   name               100 non-null    object
#  5   supply             100 non-null    float64
#  6   maxSupply          44 non-null     float64
#  7   marketCapUsd       100 non-null    float64
#  8   volumeUsd24Hr      100 non-null    float64
#  9   priceUsd           100 non-null    float64
#  10  changePercent24Hr  100 non-null    float64
#  11  vwap24Hr           98 non-null     float64
#  12  explorer           89 non-null     object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 10.3+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# id                    0
# rank                  0
# symbol                0
# name                  0
# supply                0
# maxSupply            56
# marketCapUsd          0
# volumeUsd24Hr         0
# priceUsd              0
# changePercent24Hr     0
# vwap24Hr              2
# explorer             11
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# rank                 0
# symbol               0
# name                 0
# supply               0
# maxSupply            0
# marketCapUsd         0
# volumeUsd24Hr        0
# priceUsd             0
# changePercent24Hr    0
# vwap24Hr             0
# explorer             0
# dtype: int64

# %%
df1=df[df['priceUsd']<1]
df1.head()
# Out:
#     Unnamed: 0                id  rank symbol       name        supply  \
# 7            7           cardano     8    ADA    Cardano  3.523480e+10
# 15          15           stellar    16    XLM    Stellar  3.075455e+10
# 16          16  hedera-hashgraph    17   HBAR     Hedera  4.190396e+10
# 19          19         shiba-inu    20   SHIB  Shiba Inu  5.892529e+14
# 32          32              pepe    33   PEPE       Pepe  4.206899e+14
#
#        maxSupply  marketCapUsd  volumeUsd24Hr  priceUsd  changePercent24Hr  \
# 7   4.500000e+10  2.583852e+10   5.073028e+08  0.733324           2.380598
# 15  5.000181e+10  8.853932e+09   1.675032e+08  0.287890           3.784685
# 16  5.000000e+10  8.137409e+09   1.091477e+08  0.194192           2.568369
# 19  5.895527e+14  7.590175e+09   5.987626e+07  0.000013           2.206724
# 32  4.206900e+14  3.178050e+09   4.622084e+08  0.000008           3.631454
#
#     vwap24Hr                                           explorer
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df1['name'], df1['priceUsd'],color='blue',marker='o',label='data points')
plt.title('scatter plot')
plt.legend()
plt.show()

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0       id      rank symbol     name        supply  \
# count     40.00000       40  40.00000     40       40  4.000000e+01
# unique         NaN       40       NaN     40       40           NaN
# top            NaN  bitcoin       NaN    BTC  Bitcoin           NaN
# freq           NaN        1       NaN      1        1           NaN
# mean      46.40000      NaN  47.40000    NaN      NaN  2.550103e+13
# std       29.30284      NaN  29.30284    NaN      NaN  1.130327e+14
# min        0.00000      NaN   1.00000    NaN      NaN  8.480744e+05
# 25%       19.75000      NaN  20.75000    NaN      NaN  1.493939e+08
# 50%       42.50000      NaN  43.50000    NaN      NaN  1.409444e+09
# 75%       67.25000      NaN  68.25000    NaN      NaN  2.710460e+10
# max       98.00000      NaN  99.00000    NaN      NaN  5.892529e+14
#
#            maxSupply  marketCapUsd  volumeUsd24Hr      priceUsd  \
# count   4.000000e+01  4.000000e+01   4.000000e+01     40.000000
# ...

# %%
df1=df.select_dtypes(include=['number'])
df1.head()
# Out:
#     Unnamed: 0  rank        supply     maxSupply  marketCapUsd  volumeUsd24Hr  \
# 0            0     1  1.983940e+07  2.100000e+07  1.702961e+12   1.013853e+10
# 2            2     3  5.810892e+10  1.000000e+11  1.457410e+11   3.367515e+09
# 4            4     5  1.440068e+08  1.440068e+08  9.062249e+10   5.605916e+08
# 7            7     8  3.523480e+10  4.500000e+10  2.583852e+10   5.073028e+08
# 14          14    15  2.476378e+09  5.047559e+09  9.000695e+09   7.762466e+07
#
#         priceUsd  changePercent24Hr      vwap24Hr
# 0   85837.329831           2.713718  85242.539362
# 2       2.508066           8.384786      2.492886
# 4     629.292982           2.280616    618.969678
# 7       0.733324           2.380598      0.732550
# 14      3.634620           1.597584      3.658561

# %%
df2=df.loc[2:50,['priceUsd','name']]
print(df2.head(10))
# Out:
#       priceUsd       name
# 2     2.508066        XRP
# 4   629.292982        BNB
# 7     0.733324    Cardano
# 14    3.634620    Toncoin
# 15    0.287890    Stellar
# 16    0.194192     Hedera
# 17   19.066866  Avalanche
# 18    2.471480        Sui
# 19    0.000013  Shiba Inu
# 20   92.397340   Litecoin
